# %%
import pandas as pd
import statsmodels.formula.api as smf
import geopandas as gpd

# %%
data_path = "data_collected.csv"

df = pd.read_csv(data_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246597444 entries, 0 to 246597443
# Data columns (total 9 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   year                         int64
#  1   month                        int64
#  2   day_of_week                  object
#  3   hour_of_day                  float64
#  4   origin_latitude              float64
#  5   origin_longitude             float64
#  6   destination_latitude         float64
#  7   destination_longitude        float64
#  8   estimated_average_ridership  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 16.5+ GB

# %%
df
# Out:
#            year  month day_of_week  hour_of_day  origin_latitude  \
# 0          2022      1   Wednesday         15.0        40.599300
# 1          2022      1   Wednesday         15.0        40.851695
# 2          2022      1   Wednesday         15.0        40.816104
# 3          2022      1   Wednesday         15.0        40.747141
# 4          2022      1   Wednesday         15.0        40.660476
# ...         ...    ...         ...          ...              ...
# 246597439  2025      6      Sunday         12.0        40.669847
# 246597440  2025      6      Sunday         12.0        40.581011
# 246597441  2025      6      Sunday         12.0        40.604556
# 246597442  2025      6      Sunday         12.0        40.693241
# 246597443  2025      6      Sunday         12.0        40.664635
#
#            origin_longitude  destination_latitude  destination_longitude  \
# 0                -73.955929             40.677044             -73.865050
# 1                -73.937969             40.824073             -73.893064
# 2                -73.896435             40.745494             -73.988691
# 3                -73.945032             40.747215             -73.993365
# 4                -73.830301             40.824783             -73.944216
# ...                     ...                   ...                    ...
# 246597439        -73.950466             40.660397             -73.998091
# 246597440        -73.974574             40.620769             -73.975264
# 246597441        -73.998168             40.759145             -73.953260
# 246597442        -73.990642             40.688089             -73.966839
# 246597443        -73.894895             40.799075             -73.951822
#
#            estimated_average_ridership
# 0                               0.3298
# 1                               0.3070
# 2                               0.3190
# 3                               0.2860
# 4                               0.3877
# ...                                ...
# 246597439                       0.2288
# 246597440                       0.5242
# 246597441                       0.2692
# 246597442                       1.1866
# 246597443                       0.2424
#
# [246597444 rows x 9 columns]

# %%
unique_origins = df.drop_duplicates(subset=['origin_latitude', 'origin_longitude'])[['origin_latitude', 'origin_longitude']]
unique_destinations = df.drop_duplicates(subset=['destination_latitude', 'destination_longitude'])[['destination_latitude', 'destination_longitude']]

# %%
unique_origins
# Out:
#           origin_latitude  origin_longitude
# 0               40.599300        -73.955929
# 1               40.851695        -73.937969
# 2               40.816104        -73.896435
# 3               40.747141        -73.945032
# 4               40.660476        -73.830301
# ...                   ...               ...
# 3766            40.898379        -73.854376
# 4367            40.583209        -73.827559
# 5030            40.608382        -73.815925
# 15584929        40.697466        -73.993086
# 78660877        40.636949        -74.074835
#
# [425 rows x 2 columns]

# %%
unique_destinations
# Out:
#           destination_latitude  destination_longitude
# 0                    40.677044             -73.865050
# 1                    40.824073             -73.893064
# 2                    40.745494             -73.988691
# 3                    40.747215             -73.993365
# 4                    40.824783             -73.944216
# ...                        ...                    ...
# 3992                 40.588034             -73.813641
# 4495                 40.581011             -73.974574
# 4646                 40.583209             -73.827559
# 3580616              40.697466             -73.993086
# 77328437             40.636949             -74.074835
#
# [425 rows x 2 columns]

# %%
gdf_points_origin = gpd.GeoDataFrame(
    unique_origins,
    geometry=gpd.points_from_xy(unique_origins['origin_longitude'], unique_origins['origin_latitude']),
    crs="EPSG:4326"
)

# %%
gdf_points_destination = gpd.GeoDataFrame(
    unique_destinations,
    geometry=gpd.points_from_xy(unique_destinations['destination_longitude'], unique_destinations['destination_latitude']),
    crs="EPSG:4326"
)

# %%
# Load the NYC NTA shapefile
gdf_ntas = gpd.read_file('./data/nynta2020_25c/nynta2020.shp')

# %%
gdf_ntas_origin = gdf_ntas.to_crs(gdf_points_origin.crs)
gdf_ntas_destination = gdf_ntas.to_crs(gdf_points_destination.crs)

# %%
origin_points_with_nta = gpd.sjoin(gdf_points_origin, gdf_ntas_origin, how='left', predicate='within')
destination_points_with_nta = gpd.sjoin(gdf_points_destination, gdf_ntas_destination, how='left', predicate='within')

# %%
origin_points_with_nta = origin_points_with_nta.drop(columns=[
    'index_right', 
    'Shape_Leng', 
    'Shape_Area', 
    'BoroCode', 
    'BoroName',
    'CountyFIPS', 
    'NTAType', 
    'CDTA2020', 
    'CDTAName'
])

destination_points_with_nta = destination_points_with_nta.drop(columns=[
    'index_right', 
    'Shape_Leng', 
    'Shape_Area', 
    'BoroCode', 
    'BoroName',
    'CountyFIPS', 
    'NTAType', 
    'CDTA2020', 
    'CDTAName'
])

# %%
origin_points_with_nta.rename(columns={'NTA2020': 'origin_nta2020', 'NTAName': 'origin_nta_name'}, inplace=True)
destination_points_with_nta.rename(columns={'NTA2020': 'destination_nta2020', 'NTAName': 'destination_nta_name'}, inplace=True)

# %%
origin_points_with_nta
# Out:
#           origin_latitude  origin_longitude                    geometry  \
# 0               40.599300        -73.955929   POINT (-73.95593 40.5993)
# 1               40.851695        -73.937969   POINT (-73.93797 40.8517)
# 2               40.816104        -73.896435   POINT (-73.89644 40.8161)
# 3               40.747141        -73.945032  POINT (-73.94503 40.74714)
# 4               40.660476        -73.830301   POINT (-73.8303 40.66048)
# ...                   ...               ...                         ...
# 3766            40.898379        -73.854376  POINT (-73.85438 40.89838)
# 4367            40.583209        -73.827559  POINT (-73.82756 40.58321)
# 5030            40.608382        -73.815925  POINT (-73.81592 40.60838)
# 15584929        40.697466        -73.993086  POINT (-73.99309 40.69747)
# 78660877        40.636949        -74.074835  POINT (-74.07484 40.63695)
#
#          origin_nta2020                                    origin_nta_name  \
# 0                BK1502                                            Madison
# 1                MN1202                         Washington Heights (North)
# 2                BX0202                                           Longwood
# 3                QN0201                     Long Island City-Hunters Point
# 4                QN8381              John F. Kennedy International Airport
# ...                 ...                                                ...
# 3766             BX1203                                 Wakefield-Woodlawn
# 4367             QN1403  Breezy Point-Belle Harbor-Rockaway Park-Broad ...
# 5030             QN1403  Breezy Point-Belle Harbor-Rockaway Park-Broad ...
# 15584929         BK0201                                   Brooklyn Heights
# 78660877         SI0102          Tompkinsville-Stapleton-Clifton-Fox Hills
#
#            NTAAbbrev
# 0               Mdsn
# 1           WshHts_N
# 2              Lngwd
# 3                LIC
# 4                JFK
# ...              ...
# 3766      Wkfld_Wdln
# 4367          BrzyPt
# 5030          BrzyPt
# 15584929       BkHts
# 78660877  Tkvl_Stptn
#
# [425 rows x 6 columns]

# %%
df = df.merge(
    origin_points_with_nta[['origin_latitude', 'origin_longitude', 'origin_nta2020', 'origin_nta_name']],
    on=['origin_latitude', 'origin_longitude'],
    how='left'
)

# %%
df = df.merge(
    destination_points_with_nta[['destination_latitude', 'destination_longitude', 'destination_nta2020', 'destination_nta_name']],
    on=['destination_latitude', 'destination_longitude'],
    how='left'
)

# %%
df
# Out:
#            year  month day_of_week  hour_of_day  origin_latitude  \
# 0          2022      1   Wednesday         15.0        40.599300
# 1          2022      1   Wednesday         15.0        40.851695
# 2          2022      1   Wednesday         15.0        40.816104
# 3          2022      1   Wednesday         15.0        40.747141
# 4          2022      1   Wednesday         15.0        40.660476
# ...         ...    ...         ...          ...              ...
# 246597439  2025      6      Sunday         12.0        40.669847
# 246597440  2025      6      Sunday         12.0        40.581011
# 246597441  2025      6      Sunday         12.0        40.604556
# 246597442  2025      6      Sunday         12.0        40.693241
# 246597443  2025      6      Sunday         12.0        40.664635
#
#            origin_longitude  destination_latitude  destination_longitude  \
# 0                -73.955929             40.677044             -73.865050
# 1                -73.937969             40.824073             -73.893064
# 2                -73.896435             40.745494             -73.988691
# 3                -73.945032             40.747215             -73.993365
# 4                -73.830301             40.824783             -73.944216
# ...                     ...                   ...                    ...
# 246597439        -73.950466             40.660397             -73.998091
# 246597440        -73.974574             40.620769             -73.975264
# 246597441        -73.998168             40.759145             -73.953260
# 246597442        -73.990642             40.688089             -73.966839
# 246597443        -73.894895             40.799075             -73.951822
#
#            estimated_average_ridership origin_nta2020  \
# 0                               0.3298         BK1502
# 1                               0.3070         MN1202
# 2                               0.3190         BX0202
# 3                               0.2860         QN0201
# 4                               0.3877         QN8381
# ...                                ...            ...
# 246597439                       0.2288         BK0901
# 246597440                       0.5242         BK1302
# 246597441                       0.2692         BK1101
# 246597442                       1.1866         BK0202
# 246597443                       0.2424         BK0503
#
#                                  origin_nta_name destination_nta2020  \
# 0                                        Madison              BK0505
# 1                     Washington Heights (North)              BX0202
# 2                                       Longwood              MN0501
# 3                 Long Island City-Hunters Point              MN0501
# 4          John F. Kennedy International Airport              MN0903
# ...                                          ...                 ...
# 246597439                  Crown Heights (South)              BK0702
# 246597440                  Coney Island-Sea Gate              BK1204
# 246597441                            Bensonhurst              MN0801
# 246597442    Downtown Brooklyn-DUMBO-Boerum Hill              BK0204
# 246597443                 East New York-New Lots              MN1001
#
#                                   destination_nta_name
# 0                              East New York-City Line
# 1                                             Longwood
# 2                  Midtown South-Flatiron-Union Square
# 3                  Midtown South-Flatiron-Union Square
# 4                          Hamilton Heights-Sugar Hill
# ...                                                ...
# 246597439                           Sunset Park (West)
# 246597440                      Mapleton-Midwood (West)
# 246597441  Upper East Side-Lenox Hill-Roosevelt Island
# 246597442                                 Clinton Hill
# 246597443                               Harlem (South)
#
# [246597444 rows x 13 columns]

# %%
keys = [
    "year",
    "month",
    "day_of_week",
    "hour_of_day",
    "origin_nta2020",
    "origin_nta_name",
    "destination_nta2020",
    "destination_nta_name"
]

df_agg = (
    df.groupby(keys, as_index=False, dropna=False)["estimated_average_ridership"]
      .sum()
)

# %%
df_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52506840 entries, 0 to 52506839
# Data columns (total 9 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   year                         int64
#  1   month                        int64
#  2   day_of_week                  object
#  3   hour_of_day                  float64
#  4   origin_nta2020               object
#  5   origin_nta_name              object
#  6   destination_nta2020          object
#  7   destination_nta_name         object
#  8   estimated_average_ridership  float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 3.5+ GB

# %%
df_agg
# Out:
#           year  month day_of_week  hour_of_day origin_nta2020  \
# 0         2022      1      Friday          0.0         BK0101
# 1         2022      1      Friday          0.0         BK0101
# 2         2022      1      Friday          0.0         BK0101
# 3         2022      1      Friday          0.0         BK0101
# 4         2022      1      Friday          0.0         BK0101
# ...        ...    ...         ...          ...            ...
# 52506835  2025      6   Wednesday         23.0         QN8381
# 52506836  2025      6   Wednesday         23.0         QN8381
# 52506837  2025      6   Wednesday         23.0         QN8381
# 52506838  2025      6   Wednesday         23.0         QN8381
# 52506839  2025      6   Wednesday         23.0         QN8381
#
#                                 origin_nta_name destination_nta2020  \
# 0                                    Greenpoint              BK0102
# 1                                    Greenpoint              BK0103
# 2                                    Greenpoint              BK0104
# 3                                    Greenpoint              BK0202
# 4                                    Greenpoint              BK0203
# ...                                         ...                 ...
# 52506835  John F. Kennedy International Airport              QN1002
# 52506836  John F. Kennedy International Airport              QN1201
# 52506837  John F. Kennedy International Airport              QN1401
# 52506838  John F. Kennedy International Airport              QN1402
# 52506839  John F. Kennedy International Airport              QN1403
#
#                                        destination_nta_name  \
# 0                                              Williamsburg
# 1                                        South Williamsburg
# 2                                         East Williamsburg
# 3                       Downtown Brooklyn-DUMBO-Boerum Hill
# 4                                               Fort Greene
# ...                                                     ...
# 52506835                                         Ozone Park
# 52506836                                            Jamaica
# 52506837                             Far Rockaway-Bayswater
# 52506838                    Rockaway Beach-Arverne-Edgemere
# 52506839  Breezy Point-Belle Harbor-Rockaway Park-Broad ...
#
#           estimated_average_ridership
# 0                              2.4044
# 1                              2.4761
# 2                              3.5014
# 3                              4.9075
# 4                              2.5759
# ...                               ...
# 52506835                       6.6642
# 52506836                       1.2685
# 52506837                       4.9744
# 52506838                       8.5055
# 52506839                       0.9757
#
# [52506840 rows x 9 columns]

# %%
df_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52506840 entries, 0 to 52506839
# Data columns (total 9 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   year                         int64
#  1   month                        int64
#  2   day_of_week                  object
#  3   hour_of_day                  float64
#  4   origin_nta2020               object
#  5   origin_nta_name              object
#  6   destination_nta2020          object
#  7   destination_nta_name         object
#  8   estimated_average_ridership  float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 3.5+ GB

# %%
df_agg.to_csv('data_agg.csv', index=False)
